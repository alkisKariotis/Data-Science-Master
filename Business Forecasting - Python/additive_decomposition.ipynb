# %%
import pandas as pd

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
from matplotlib import pyplot

# %%
df=pd.read_excel(r"C:\Users\ZarasAndreas\Documents\Documents\Courses Taught by Me\Forecasting Course_FINAL\FINAL\Course Presentations\Python\Sales_Data_Additive_Decomposition - Python.xlsx")

# %%
df
# Out:
#          Date  Sales
# 0  1984-01-01     20
# 1  1984-04-01     12
# 2  1984-07-01     10
# 3  1984-10-01     18
# 4  1985-01-01     23
# 5  1985-04-01     14
# 6  1985-07-01     13
# 7  1985-10-01     22
# 8  1986-01-01     28
# 9  1986-04-01     18
# 10 1986-07-01     17
# 11 1986-10-01     26
# 12 1987-01-01     30
# 13 1987-04-01     21
# 14 1987-07-01     20
# 15 1987-10-01     28
# 16 1988-01-01     33
# 17 1988-04-01     23
# 18 1988-07-01     25
# 19 1988-10-01     34
# 20 1989-01-01     37
# 21 1989-04-01     27
# 22 1989-07-01     26
# 23 1989-10-01     36
# 24 1990-01-01     40
# 25 1990-04-01     28
# 26 1990-07-01     29
# 27 1990-10-01     40
# 28 1991-01-01     43
# 29 1991-04-01     34
# 30 1991-07-01     32
# 31 1991-10-01     42
# 32 1992-01-01     46
# 33 1992-04-01     36
# 34 1992-07-01     34
# 35 1992-10-01     46
# 36 1993-01-01     48
# 37 1993-04-01     36
# 38 1993-07-01     36
# 39 1993-10-01     51

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df
# Out:
#          Date  Sales
# 0  1984-01-01     20
# 1  1984-04-01     12
# 2  1984-07-01     10
# 3  1984-10-01     18
# 4  1985-01-01     23
# 5  1985-04-01     14
# 6  1985-07-01     13
# 7  1985-10-01     22
# 8  1986-01-01     28
# 9  1986-04-01     18
# 10 1986-07-01     17
# 11 1986-10-01     26
# 12 1987-01-01     30
# 13 1987-04-01     21
# 14 1987-07-01     20
# 15 1987-10-01     28
# 16 1988-01-01     33
# 17 1988-04-01     23
# 18 1988-07-01     25
# 19 1988-10-01     34
# 20 1989-01-01     37
# 21 1989-04-01     27
# 22 1989-07-01     26
# 23 1989-10-01     36
# 24 1990-01-01     40
# 25 1990-04-01     28
# 26 1990-07-01     29
# 27 1990-10-01     40
# 28 1991-01-01     43
# 29 1991-04-01     34
# 30 1991-07-01     32
# 31 1991-10-01     42
# 32 1992-01-01     46
# 33 1992-04-01     36
# 34 1992-07-01     34
# 35 1992-10-01     46
# 36 1993-01-01     48
# 37 1993-04-01     36
# 38 1993-07-01     36
# 39 1993-10-01     51

# %%
df=df.set_index("Date")

# %%
df
# Out:
#             Sales
# Date
# 1984-01-01     20
# 1984-04-01     12
# 1984-07-01     10
# 1984-10-01     18
# 1985-01-01     23
# 1985-04-01     14
# 1985-07-01     13
# 1985-10-01     22
# 1986-01-01     28
# 1986-04-01     18
# 1986-07-01     17
# 1986-10-01     26
# 1987-01-01     30
# 1987-04-01     21
# 1987-07-01     20
# 1987-10-01     28
# 1988-01-01     33
# 1988-04-01     23
# 1988-07-01     25
# 1988-10-01     34
# 1989-01-01     37
# 1989-04-01     27
# 1989-07-01     26
# 1989-10-01     36
# 1990-01-01     40
# 1990-04-01     28
# 1990-07-01     29
# 1990-10-01     40
# 1991-01-01     43
# 1991-04-01     34
# 1991-07-01     32
# 1991-10-01     42
# 1992-01-01     46
# 1992-04-01     36
# 1992-07-01     34
# 1992-10-01     46
# 1993-01-01     48
# 1993-04-01     36
# 1993-07-01     36
# 1993-10-01     51

# %%
result = seasonal_decompose(df, model='additive')

# %%
result.plot()

# %%
trend=result.trend

# %%
seasonal=result.seasonal

# %%
resid=result.resid

# %%
trend_df=pd.DataFrame(trend)

# %%
trend_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
seasonal_df=pd.DataFrame(seasonal)

# %%
seasonal_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
