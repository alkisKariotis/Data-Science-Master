# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r'C:\Users\ZarasAndreas\Documents\Documents\Courses Taught by Me\Forecasting Course_FINAL\FINAL\Course Presentations\Python\Beer_Time_Series_Reg - Python.xls')

# %%
df
# Out:
#          Date  Beert   t  D1  D2  D3
# 0  1996-01-01  14000   1   1   0   0
# 1  1996-04-01  16950   2   0   1   0
# 2  1996-07-01  16100   3   0   0   1
# 3  1996-10-01  15032   4   0   0   0
# 4  1997-01-01  13342   5   1   0   0
# 5  1997-04-01  16288   6   0   1   0
# 6  1997-07-01  15294   7   0   0   1
# 7  1997-10-01  14766   8   0   0   0
# 8  1998-01-01  12767   9   1   0   0
# 9  1998-04-01  15812  10   0   1   0
# 10 1998-07-01  15249  11   0   0   1
# 11 1998-10-01  14052  12   0   0   0
# 12 1999-01-01  13174  13   1   0   0
# 13 1999-04-01  15507  14   0   1   0
# 14 1999-07-01  14902  15   0   0   1
# 15 1999-10-01  14707  16   0   0   0
# 16 2000-01-01  12834  17   1   0   0
# 17 2000-04-01  14998  18   0   1   0
# 18 2000-07-01  14717  19   0   0   1
# 19 2000-10-01  14165  20   0   0   0
# 20 2001-01-01  12339  21   1   0   0
# 21 2001-04-01  14684  22   0   1   0
# 22 2001-07-01  13800  23   0   0   1
# 23 2001-10-01  12200  24   0   0   0

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df=df.set_index("Date")

# %%
df
# Out:
#             Beert   t  D1  D2  D3
# Date
# 1996-01-01  14000   1   1   0   0
# 1996-04-01  16950   2   0   1   0
# 1996-07-01  16100   3   0   0   1
# 1996-10-01  15032   4   0   0   0
# 1997-01-01  13342   5   1   0   0
# 1997-04-01  16288   6   0   1   0
# 1997-07-01  15294   7   0   0   1
# 1997-10-01  14766   8   0   0   0
# 1998-01-01  12767   9   1   0   0
# 1998-04-01  15812  10   0   1   0
# 1998-07-01  15249  11   0   0   1
# 1998-10-01  14052  12   0   0   0
# 1999-01-01  13174  13   1   0   0
# 1999-04-01  15507  14   0   1   0
# 1999-07-01  14902  15   0   0   1
# 1999-10-01  14707  16   0   0   0
# 2000-01-01  12834  17   1   0   0
# 2000-04-01  14998  18   0   1   0
# 2000-07-01  14717  19   0   0   1
# 2000-10-01  14165  20   0   0   0
# 2001-01-01  12339  21   1   0   0
# 2001-04-01  14684  22   0   1   0
# 2001-07-01  13800  23   0   0   1
# 2001-10-01  12200  24   0   0   0

# %%
y= df['Beert'].to_numpy()

# %%
y
# Out:
# array([14000, 16950, 16100, 15032, 13342, 16288, 15294, 14766, 12767,
#        15812, 15249, 14052, 13174, 15507, 14902, 14707, 12834, 14998,
#        14717, 14165, 12339, 14684, 13800, 12200], dtype=int64)

# %%
x=df.iloc[:,[1,2,3,4]].values

# %%
x
# Out:
# array([[ 1,  1,  0,  0],
#        [ 2,  0,  1,  0],
#        [ 3,  0,  0,  1],
#        [ 4,  0,  0,  0],
#        [ 5,  1,  0,  0],
#        [ 6,  0,  1,  0],
#        [ 7,  0,  0,  1],
#        [ 8,  0,  0,  0],
#        [ 9,  1,  0,  0],
#        [10,  0,  1,  0],
#        [11,  0,  0,  1],
#        [12,  0,  0,  0],
#        [13,  1,  0,  0],
#        [14,  0,  1,  0],
#        [15,  0,  0,  1],
#        [16,  0,  0,  0],
#        [17,  1,  0,  0],
#        [18,  0,  1,  0],
#        [19,  0,  0,  1],
#        [20,  0,  0,  0],
#        [21,  1,  0,  0],
#        [22,  0,  1,  0],
#        [23,  0,  0,  1],
#        [24,  0,  0,  0]], dtype=int64)

# %%
model = LinearRegression().fit(x, y)

# %%
model
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 15498.991666666667

# %%
model.coef_
# Out:
# array([  -96.09464286, -1365.95059524,  1360.64404762,   760.57202381])

# %%
y_pred = model.predict(x)

# %%
y_pred
# Out:
# array([14036.94642857, 16667.44642857, 15971.2797619 , 15114.61309524,
#        13652.56785714, 16283.06785714, 15586.90119048, 14730.23452381,
#        13268.18928571, 15898.68928571, 15202.52261905, 14345.85595238,
#        12883.81071429, 15514.31071429, 14818.14404762, 13961.47738095,
#        12499.43214286, 15129.93214286, 14433.76547619, 13577.09880952,
#        12115.05357143, 14745.55357143, 14049.38690476, 13192.7202381 ])

# %%
y_pred_df=pd.DataFrame(y_pred,columns=["y_pred"])

# %%
y_pred_df
# Out:
#           y_pred
# 0   14036.946429
# 1   16667.446429
# 2   15971.279762
# 3   15114.613095
# 4   13652.567857
# 5   16283.067857
# 6   15586.901190
# 7   14730.234524
# 8   13268.189286
# 9   15898.689286
# 10  15202.522619
# 11  14345.855952
# 12  12883.810714
# 13  15514.310714
# 14  14818.144048
# 15  13961.477381
# 16  12499.432143
# 17  15129.932143
# 18  14433.765476
# 19  13577.098810
# 20  12115.053571
# 21  14745.553571
# 22  14049.386905
# 23  13192.720238

# %%
y_pred_df["Date"] = pd.date_range('1996-01-01', periods=24,freq='QS')
y_pred_df
# Out:
#           y_pred       Date
# 0   14036.946429 1996-01-01
# 1   16667.446429 1996-04-01
# 2   15971.279762 1996-07-01
# 3   15114.613095 1996-10-01
# 4   13652.567857 1997-01-01
# 5   16283.067857 1997-04-01
# 6   15586.901190 1997-07-01
# 7   14730.234524 1997-10-01
# 8   13268.189286 1998-01-01
# 9   15898.689286 1998-04-01
# 10  15202.522619 1998-07-01
# 11  14345.855952 1998-10-01
# 12  12883.810714 1999-01-01
# 13  15514.310714 1999-04-01
# 14  14818.144048 1999-07-01
# 15  13961.477381 1999-10-01
# 16  12499.432143 2000-01-01
# 17  15129.932143 2000-04-01
# 18  14433.765476 2000-07-01
# 19  13577.098810 2000-10-01
# 20  12115.053571 2001-01-01
# 21  14745.553571 2001-04-01
# 22  14049.386905 2001-07-01
# 23  13192.720238 2001-10-01

# %%
historical_df=pd.merge(df,y_pred_df,on="Date",how="inner")

# %%
historical_df.set_index("Date")
# Out:
#             Beert   t  D1  D2  D3        y_pred
# Date
# 1996-01-01  14000   1   1   0   0  14036.946429
# 1996-04-01  16950   2   0   1   0  16667.446429
# 1996-07-01  16100   3   0   0   1  15971.279762
# 1996-10-01  15032   4   0   0   0  15114.613095
# 1997-01-01  13342   5   1   0   0  13652.567857
# 1997-04-01  16288   6   0   1   0  16283.067857
# 1997-07-01  15294   7   0   0   1  15586.901190
# 1997-10-01  14766   8   0   0   0  14730.234524
# 1998-01-01  12767   9   1   0   0  13268.189286
# 1998-04-01  15812  10   0   1   0  15898.689286
# 1998-07-01  15249  11   0   0   1  15202.522619
# 1998-10-01  14052  12   0   0   0  14345.855952
# 1999-01-01  13174  13   1   0   0  12883.810714
# 1999-04-01  15507  14   0   1   0  15514.310714
# 1999-07-01  14902  15   0   0   1  14818.144048
# 1999-10-01  14707  16   0   0   0  13961.477381
# 2000-01-01  12834  17   1   0   0  12499.432143
# 2000-04-01  14998  18   0   1   0  15129.932143
# ...

# %%
historical_df[["y_pred","Beert"]].plot()
# Out:
# <AxesSubplot:>

# %%
df_future=pd.read_excel(r'C:\Users\ZarasAndreas\Documents\Documents\Courses Taught by Me\Forecasting Course_FINAL\FINAL\Course Presentations\Python\Beer_Time_Series_Reg - Predict - Python.xlsx')

# %%
df_future
# Out:
#         Date   t  D1  D2  D3
# 0 2002-01-01  25   1   0   0
# 1 2002-04-01  26   0   1   0
# 2 2002-07-01  27   0   0   1
# 3 2002-10-01  28   0   0   0
# 4 2003-01-01  29   1   0   0
# 5 2003-04-01  30   0   1   0
# 6 2003-07-01  31   0   0   1
# 7 2003-10-01  32   0   0   0

# %%
x_future=df_future.iloc[:,[1,2,3,4]].values
x_future
# Out:
# array([[25,  1,  0,  0],
#        [26,  0,  1,  0],
#        [27,  0,  0,  1],
#        [28,  0,  0,  0],
#        [29,  1,  0,  0],
#        [30,  0,  1,  0],
#        [31,  0,  0,  1],
#        [32,  0,  0,  0]], dtype=int64)

# %%
future_pred=model.predict(x_future)
future_pred
# Out:
# array([11730.675     , 14361.175     , 13665.00833333, 12808.34166667,
#        11346.29642857, 13976.79642857, 13280.6297619 , 12423.96309524])

# %%
future_pred_df=pd.DataFrame(future_pred,columns=["future_pred"])

# %%
future_pred_df["Date"] = pd.date_range('2002-01-01', periods=8,freq='QS')

# %%
future_pred_df=future_pred_df.set_index("Date")

# %%
future_pred_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
