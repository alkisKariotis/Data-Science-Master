# %%
import pandas as pd

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
import pmdarima

# %%
from statsmodels.tsa.stattools import adfuller

# %%
df=pd.read_excel(r'C:\Users\ZarasAndreas\Documents\Documents\Courses Taught by Me\Forecasting Course_FINAL\FINAL\Course Presentations\Python\Demo_Beer_ACF - Python.xls')

# %%
df
# Out:
#      Beer       Date
# 0   14000 1995-01-01
# 1   16950 1995-04-01
# 2   16100 1995-07-01
# 3   15032 1995-10-01
# 4   13342 1996-01-01
# 5   16288 1996-04-01
# 6   15294 1996-07-01
# 7   14766 1996-10-01
# 8   12767 1997-01-01
# 9   15812 1997-04-01
# 10  15249 1997-07-01
# 11  14052 1997-10-01
# 12  13174 1998-01-01
# 13  15507 1998-04-01
# 14  14902 1998-07-01
# 15  14707 1998-10-01
# 16  12834 1999-01-01
# 17  14998 1999-04-01
# 18  14717 1999-07-01
# 19  14165 1999-10-01
# 20  12339 2000-01-01
# 21  14684 2000-04-01
# 22  13800 2000-07-01
# 23  12200 2000-10-01

# %%
df=df.set_index("Date")

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plot_acf(df,lags=20,alpha=0.05)

# %%
plot_pacf(df,lags=10)
# Out:
# C:\Users\ZarasAndreas\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
pmdarima.arima.nsdiffs(df['Beer'],m=4)
# Out:
# 1

# %%
df_seasonal_diff = df.diff(4)

# %%
df_seasonal_diff
# Out:
#               Beer
# Date
# 1995-01-01     NaN
# 1995-04-01     NaN
# 1995-07-01     NaN
# 1995-10-01     NaN
# 1996-01-01  -658.0
# 1996-04-01  -662.0
# 1996-07-01  -806.0
# 1996-10-01  -266.0
# 1997-01-01  -575.0
# 1997-04-01  -476.0
# 1997-07-01   -45.0
# 1997-10-01  -714.0
# 1998-01-01   407.0
# 1998-04-01  -305.0
# 1998-07-01  -347.0
# 1998-10-01   655.0
# 1999-01-01  -340.0
# 1999-04-01  -509.0
# 1999-07-01  -185.0
# 1999-10-01  -542.0
# 2000-01-01  -495.0
# 2000-04-01  -314.0
# 2000-07-01  -917.0
# 2000-10-01 -1965.0

# %%
df_seasonal_diff=df_seasonal_diff.dropna()

# %%
df_seasonal_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pmdarima.arima.nsdiffs(df_seasonal_diff['Beer'],m=4)
# Out:
# 0

# %%
adfuller(df_seasonal_diff)
# Out:
# (-0.21294967754047422,
#  0.9369603441752132,
#  2,
#  17,
#  {'1%': -3.889265672705068,
#   '5%': -3.0543579727254224,
#   '10%': -2.66698384083045},
#  171.12702280245782)

# %%
df_seasonal_diff_first_diff = df_seasonal_diff.diff(1)

# %%
df_seasonal_diff_first_diff=df_seasonal_diff_first_diff.dropna()
# Out:
#               Beer
# Date
# 1996-04-01    -4.0
# 1996-07-01  -144.0
# 1996-10-01   540.0
# 1997-01-01  -309.0
# 1997-04-01    99.0
# 1997-07-01   431.0
# 1997-10-01  -669.0
# 1998-01-01  1121.0
# 1998-04-01  -712.0
# 1998-07-01   -42.0
# 1998-10-01  1002.0
# 1999-01-01  -995.0
# 1999-04-01  -169.0
# 1999-07-01   324.0
# 1999-10-01  -357.0
# 2000-01-01    47.0
# 2000-04-01   181.0
# 2000-07-01  -603.0
# 2000-10-01 -1048.0

# %%
df_seasonal_diff_first_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adfuller(df_seasonal_diff_first_diff)
# Out:
# (0.4287335514230523,
#  0.9825382492069862,
#  6,
#  12,
#  {'1%': -4.137829282407408,
#   '5%': -3.1549724074074077,
#   '10%': -2.7144769444444443},
#  171.4212084586031)

# %%
df_seasonal_diff_second_diff = df_seasonal_diff_first_diff.diff(1)

# %%
df_seasonal_diff_second_diff=df_seasonal_diff_second_diff.dropna()

# %%
df_seasonal_diff_second_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adfuller(df_seasonal_diff_second_diff)
# Out:
# (-2.6689864908257936,
#  0.07956042213803516,
#  5,
#  12,
#  {'1%': -4.137829282407408,
#   '5%': -3.1549724074074077,
#   '10%': -2.7144769444444443},
#  154.24268966056394)
