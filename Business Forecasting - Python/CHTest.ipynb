# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# !pip install pmdarima

# %%
import pmdarima

# %%
from statsmodels.tsa.stattools import adfuller

# %%
df=pd.read_excel(r"C:\Users\ZarasAndreas\Documents\Documents\Courses Taught by Me\Forecasting Course_FINAL\FINAL\Course Presentations\Python\Demo_Beer_Autocorrelation_CH - Python.xls")

# %%
df=df.set_index('Date')

# %%
df
# Out:
#             Beert
# Date
# 1996-01-01  14000
# 1996-04-01  16950
# 1996-07-01  16100
# 1996-10-01  15032
# 1997-01-01  13342
# 1997-04-01  16288
# 1997-07-01  15294
# 1997-10-01  14766
# 1998-01-01  12767
# 1998-04-01  15812
# 1998-07-01  15249
# 1998-10-01  14052
# 1999-01-01  13174
# 1999-04-01  15507
# 1999-07-01  14902
# 1999-10-01  14707
# 2000-01-01  12834
# 2000-04-01  14998
# 2000-07-01  14717
# 2000-10-01  14165
# 2001-01-01  12339
# 2001-04-01  14684
# 2001-07-01  13800
# 2001-10-01  12200

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pmdarima.arima.nsdiffs(df['Beert'],m=4)
# Out:
# 1

# %%
df_seasonal_diff=df.diff(4)

# %%
df_seasonal_diff=df_seasonal_diff.dropna()

# %%
df_seasonal_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pmdarima.arima.nsdiffs(df_seasonal_diff['Beert'],m=4)
# Out:
# 0

# %%
adfuller(df_seasonal_diff)
# Out:
# (-0.21294967754047422,
#  0.9369603441752132,
#  2,
#  17,
#  {'1%': -3.889265672705068,
#   '5%': -3.0543579727254224,
#   '10%': -2.66698384083045},
#  171.12702280245782)

# %%
df_seasonal_diff_first_diff=df_seasonal_diff.diff(1)

# %%
df_seasonal_diff_first_diff=df_seasonal_diff_first_diff.dropna()

# %%
df_seasonal_diff_first_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adfuller(df_seasonal_diff_first_diff)
# Out:
# (0.4287335514230523,
#  0.9825382492069862,
#  6,
#  12,
#  {'1%': -4.137829282407408,
#   '5%': -3.1549724074074077,
#   '10%': -2.7144769444444443},
#  171.4212084586031)

# %%
df_seasonal_diff_first_diff_second_diff=df_seasonal_diff_first_diff.diff(1)

# %%
df_seasonal_diff_first_diff_second_diff=df_seasonal_diff_first_diff_second_diff.dropna()

# %%
df_seasonal_diff_first_diff_second_diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adfuller(df_seasonal_diff_first_diff_second_diff)
# Out:
# (-2.6689864908257936,
#  0.07956042213803516,
#  5,
#  12,
#  {'1%': -4.137829282407408,
#   '5%': -3.1549724074074077,
#   '10%': -2.7144769444444443},
#  154.24268966056394)
