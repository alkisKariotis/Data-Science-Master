# %%
import pandas as pd

# %%
import numpy as np

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
s = 2*np.random.uniform(1,9,100)-10

# %%
s
# Out:
# array([ 6.39226953,  3.17989109,  5.68422858, -4.30692584, -6.59413604,
#        -6.47434508, -2.64214438,  6.14547741,  3.1276742 , -1.86262099,
#         4.06565401, -0.42673924,  1.13161455, -1.93138934, -4.7405309 ,
#         7.38417346, -5.40582049,  0.89227298,  0.72363687,  2.58680234,
#        -0.59479119, -4.83334231,  4.28367538,  1.11142916, -7.28860718,
#        -3.76897454,  7.57953021,  7.14869963,  6.43747907, -0.28146353,
#        -7.53458894, -4.62803986,  4.4268102 , -6.85708725,  7.42969169,
#         6.15984373, -5.78848321,  0.44498631, -4.95785974, -4.11988079,
#        -2.63578267,  1.65975661, -2.62240316,  4.25304161, -1.85890527,
#         0.526476  , -2.02136538,  5.22637852, -4.92322527,  2.98605869,
#         3.75109228, -4.81979895,  1.74707384, -3.76137377,  6.63514358,
#        -4.06214626, -7.08774193,  2.19897913, -5.78093863,  2.95399701,
#         1.35915082, -0.18157847, -7.05347557, -3.06732017, -0.2716964 ,
# ...

# %%
plot_acf(s)
