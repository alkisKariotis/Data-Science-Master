# %%
import pymysql

# Open database connection
#mysql_config --socket  to get the socket


#Create a database for supplierProduct,delete it if it exists
# it deletes it
# Also create tables, which are empty initially. The tables will be 
# populated with data form the command prompt

# Open database connection
db = pymysql.connect(host="localhost",
                     user="ds",
                     passwd="0019cg!CG!",
                     ## Check if this is needed
                     unix_socket="/var/run/mysqld/mysqld.sock" )

cursor=db.cursor()

cursor.execute("DROP DATABASE IF EXISTS supplierProduct");


#create a database 
cursor.execute("create database supplierProduct")

#make it current
cursor.execute("use supplierProduct")



# Create supplier table
sql1 = """CREATE TABLE supplier (
         id  CHAR(20) NOT NULL primary key,
         name  CHAR(20),
         status INT,  
         city CHAR(20))"""

# Create product table
sql2 = """CREATE TABLE product (
         id  CHAR(20) NOT NULL primary key,
         name  CHAR(20),
         color CHAR(20),
         weight  float,  
         city CHAR(20))"""

#create supplierProduct table
sql3 = """CREATE TABLE supplierProduct2 (
         sid   CHAR(20), 
         foreign key (sid) references supplier(id),
         pid char(20), 
         qty INT,
         foreign key (pid) references product(id),
         primary key(sid,pid))"""
         

#this is where the queries are executed
cursor.execute(sql1)
cursor.execute(sql2)
cursor.execute(sql3)



# disconnect from server
db.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.8/site-packages/pymysql/connections.py:633, in Connection.connect(self, sock)
#     632 sock.settimeout(self.connect_timeout)
# --> 633 sock.connect(self.unix_socket)
#     634 self.host_info = "Localhost via UNIX socket"
#
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 13
#       1 import pymysql
#       3 # Open database connection
#       4 #mysql_config --socket  to get the socket
#       5
#    (...)
#      11
#      12 # Open database connection
# ---> 13 db = pymysql.connect(host="localhost",
#      14                      user="ds",
#      15                      passwd="0019cg!CG!",
#      16                      unix_socket="/var/run/mysqld/mysqld.sock" )
#      18 cursor=db.cursor()
#      20 cursor.execute("DROP DATABASE IF EXISTS supplierProduct");
#
# File ~/miniconda3/lib/python3.8/site-packages/pymysql/connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# --> 358     self.connect()
#
# File ~/miniconda3/lib/python3.8/site-packages/pymysql/connections.py:711, in Connection.connect(self, sock)
#     709     if DEBUG:
#     710         print(exc.traceback)
# --> 711     raise exc
#     713 # If e is neither DatabaseError or IOError, It's a bug.
#     714 # But raising AssertionError hides original error.
#     715 # So just reraise it.
#     716 raise
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([Errno 2] No such file or directory)")

# %%
# !conda install -c anaconda pymysql
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-arm64::python_abi==3.8=3_cp38
#   - conda-forge/osx-arm64::ansi2html==1.8.0=py38h10201cd_1
#   - conda-forge/osx-arm64::unicodedata2==15.0.0=py38hb991d35_0
#   - conda-forge/noarch::jupyter-dash==0.4.2=pyhd8ed1ab_1
# unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-arm64::python_abi==3.8=3_cp38
#   - conda-forge/osx-arm64::ansi2html==1.8.0=py38h10201cd_1
#   - defaults/osx-arm64::notebook==6.5.2=py38hca03da5_0
#   - conda-forge/osx-arm64::unicodedata2==15.0.0=py38hb991d35_0
#   - conda-forge/noarch::jupyter-dash==0.4.2=pyhd8ed1ab_1
# unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - ansi2html -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.8,<3.9.0a0',build=*_cpython]
#   - ansi2html -> python[version='>=3.12,<3.13.0a0']
#   - argon2-cffi -> python[version='>=3.10,<3.11.0a0|>=3.11,<3.12.0a0']
#   - fonttools -> python[version='>=3.10,<3.11.0a0|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0',build=*_cpython]
#   - jinja2 -> python[version='>=3.12,<3.13.0a0']
#   - joblib -> python[version='>=3.12,<3.13.0a0']
#   - jsonschema -> python[version='>=3.12,<3.13.0a0']
#   - jupyter-dash -> python[version='>=3.6|>=3.8,<3.9.0a0|>=3.8',build=*_cpython]
#   - pygments -> python[version='>=3.12,<3.13.0a0']
#   - ruamel.yaml -> python[version='>=3.12,<3.13.0a0']
#   - unicodedata2 -> python[version='>=3.10,<3.11.0a0|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0',build=*_cpython]
#   - wheel -> python[version='>=3.12,<3.13.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package sqlite conflicts for:
# argon2-cffi -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# tinycss2 -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# python-json-logger -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# prometheus_client -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# pymysql -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# nbclient -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# pysocks -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# munkres -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# terminado -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# squarify -> python[version='>=2.6,<=2.7|>=3.5'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# entrypoints -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# plotly -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# importlib_resources -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# itsdangerous -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# brotli-python -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# conda-package-handling -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# ipython_genutils -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# ruamel.yaml.clib -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# platformdirs -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# jsonschema -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# matplotlib -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jupyterlab_pygments -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# packaging -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pooch -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# tenacity -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# ansi2html -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# cffi -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# flit-core -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# nbclassic -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# anyio -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# pyyaml -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# python=3.8 -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0']
# ruamel.yaml -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# joblib -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# matplotlib-inline -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# backports -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pluggy -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# nest-asyncio -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# notebook-shim -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# idna -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# python.app -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# certifi -> python[version='>=3.12,<3.13.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# bleach -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pytz -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# urllib3 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jupyter_events -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# notebook -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# cycler -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# kiwisolver -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# wcwidth -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jupyter_server_terminals -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# requests -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jupyter_client -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pip -> python[version='>=3.12,<3.13.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# bottleneck -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# defusedxml -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# parso -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# attrs -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# python-dateutil -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# rfc3339-validator -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# python-fastjsonschema -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pandas -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# beautifulsoup4 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# lxml -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# contourpy -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# numexpr -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pycosat -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# jupyter-dash -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# backcall -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# websocket-client -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pyrsistent -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# _ipython_minor_entry_point -> python=3.8 -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0']
# dash -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# prompt-toolkit -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# jsonpointer -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jsonpatch -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# tqdm -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# soupsieve -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# numpy -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jinja2 -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# flask -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# click -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# importlib-metadata -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# pillow -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pycparser -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# conda[version='>=23.7.4'] -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pygments -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# executing -> python[version='>=2.7'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# send2trash -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# flask-compress -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# babel -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# unicodedata2 -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# pickleshare -> python[version='>=3'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# appnope -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# nbconvert -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# debugpy -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# stack_data -> python[version='>=3.5'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# matplotlib-base -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# comm -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# boltons -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# threadpoolctl -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# typing_extensions -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# six -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# wheel -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# pyopenssl -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jupyter_server -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# zipp -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# zstandard -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# backports.functools_lru_cache -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# brotlipy -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# nbformat -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# numpy-base -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# json5 -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# tornado -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jupyter_core -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# charset-normalizer -> python[version='>=3.5'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# branca -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# psutil -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pexpect -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# sniffio -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# markupsafe -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# asttokens -> python[version='>=3.5'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# mistune -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# toolz -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# ipython -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.37.2,<4.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# setuptools -> python[version='>=3.12,<3.13.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.38.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.3,<4.0a0|>=3.39.2,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0']
# werkzeug -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# retrying -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# rfc3986-validator -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# decorator -> python[version='>=3.5'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# folium -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pkgutil-resolve-name -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0']
# tomli -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# webencodings -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# traitlets -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pyparsing -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0']
# typing-extensions -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# jedi -> python[version='>=3.11,<3.12.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# fonttools -> python[version='>=3.6'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# pure_eval -> python[version='>=3.5'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.35.4,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.37.2,<4.0a0|>=3.36.0,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# ptyprocess -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
# appdirs -> python -> sqlite[version='>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.37.2,<4.0a0|>=3.38.0,<4.0a0|>=3.39.3,<4.0a0|>=3.40.0,<4.0a0|>=3.40.1,<4.0a0|>=3.41.1,<4.0a0|>=3.41.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0']
#
# Package libffi conflicts for:
# brotlipy -> cffi[version='>=1.0.0'] -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<4.0a0|>=3.3|>=3.4,<3.5|>=3.4,<4.0a0']
# jupyter-dash -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# folium -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# beautifulsoup4 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# numpy -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# tornado -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# tinycss2 -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# appdirs -> python -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# typing-extensions -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# python-json-logger -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# python=3.8 -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pytz -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# fonttools -> python[version='>=3.6'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# click -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pexpect -> python -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pymysql -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pyyaml -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# matplotlib -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# dash -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pluggy -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# nest-asyncio -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# itsdangerous -> python[version='>=3.6'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# send2trash -> python -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# nbclassic -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# tenacity -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# flask -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# notebook-shim -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# markupsafe -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# cffi -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<4.0a0|>=3.3|>=3.4,<3.5']
# notebook -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pygments -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pycosat -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# bottleneck -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# zstandard -> cffi[version='>=1.11'] -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<4.0a0|>=3.3|>=3.4,<3.5|>=3.4,<4.0a0']
# debugpy -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# ansi2html -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# typing_extensions -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# stack_data -> python[version='>=3.5'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# backports -> python -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# webencodings -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# jupyter_core -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pyrsistent -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# idna -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# rfc3339-validator -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# flit-core -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# six -> python -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# psutil -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# certifi -> python[version='>=3.12,<3.13.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# rfc3986-validator -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# brotli-python -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# joblib -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pysocks -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# nbformat -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# ptyprocess -> python -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# flask-compress -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# wcwidth -> python -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pure_eval -> python[version='>=3.5'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# charset-normalizer -> python[version='>=3.5'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# ruamel.yaml.clib -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# branca -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# requests -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pillow -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# anyio -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# soupsieve -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# urllib3 -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# appnope -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# parso -> python[version='>=3.6'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# terminado -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# cffi -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.4,<4.0a0']
# babel -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# plotly -> python[version='>=3.11,<3.12.0a0'] -> libffi[version='>=3.3,<4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# ...
#
# Package wcwidth conflicts for:
# ipython -> prompt-toolkit[version='>3.0.30,<3.1.0,!=3.0.37'] -> wcwidth
# prompt-toolkit -> wcwidth
#
# Package rfc3339-validator conflicts for:
# jupyter_server -> jupyter_events[version='>=0.4.0'] -> rfc3339-validator
# jupyter_events -> rfc3339-validator
#
# Package backports.functools_lru_cache conflicts for:
# prompt-toolkit -> wcwidth -> backports.functools_lru_cache
# wcwidth -> backports.functools_lru_cache
#
# Package flit-core conflicts for:
# typing_extensions -> flit-core[version='>=3.6,<4']
# ipython -> typing_extensions -> flit-core[version='>=3.6,<4']
# typing-extensions -> typing_extensions==4.4.0=py311hca03da5_0 -> flit-core[version='>=3.6,<4']
#
# Package argon2-cffi-bindings conflicts for:
# nbclassic -> argon2-cffi -> argon2-cffi-bindings
# notebook -> argon2-cffi -> argon2-cffi-bindings
# jupyter_server -> argon2-cffi -> argon2-cffi-bindings
# argon2-cffi -> argon2-cffi-bindings
#
# Package zstd conflicts for:
# pillow -> libtiff[version='>=4.2.0,<5.0a0'] -> zstd[version='>=1.4.9,<1.5.0a0|>=1.5.2,<1.6.0a0']
# libtiff -> zstd[version='>=1.4.9,<1.5.0a0|>=1.5.2,<1.6.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> zstd[version='>=1.4.9,<1.5.0a0|>=1.5.2,<1.6.0a0']
# libwebp -> libtiff[version='>=4.2.0,<5.0a0'] -> zstd[version='>=1.4.9,<1.5.0a0|>=1.5.2,<1.6.0a0']
#
# Package brotli-python conflicts for:
# urllib3 -> brotli-python[version='>=1.0.9']
# dash -> flask-compress -> brotli-python
# flask-compress -> brotli-python
#
# Package flask-compress conflicts for:
# jupyter-dash -> dash -> flask-compress
# dash -> flask-compress
#
# Package comm conflicts for:
# nbclassic -> ipykernel -> comm[version='>=0.1|>=0.1.1']
# notebook -> ipykernel -> comm[version='>=0.1|>=0.1.1']
# jupyter-dash -> ipykernel -> comm[version='>=0.1|>=0.1.1']
# ipykernel -> comm[version='>=0.1|>=0.1.1']
#
# Package libtiff conflicts for:
# libwebp -> libtiff[version='>=4.2.0,<5.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> libtiff[version='>=4.2.0,<5.0a0']
# pillow -> libtiff[version='>=4.2.0,<5.0a0']
#
# Package zipp conflicts for:
# importlib-metadata -> zipp[version='>=0.5']
# matplotlib-base -> importlib_resources[version='>=5.2.0'] -> zipp[version='>=3.1.0']
# jsonschema -> importlib_resources[version='>=1.4.0'] -> zipp[version='>=3.1.0']
# click -> importlib-metadata -> zipp[version='>=0.5']
# flask -> importlib-metadata[version='>=3.6.0'] -> zipp[version='>=0.5']
# importlib_resources -> zipp[version='>=3.1.0']
# importlib_metadata -> importlib-metadata[version='>=6.0.0,<6.0.1.0a0'] -> zipp[version='>=0.5']
#
# Package zeromq conflicts for:
# notebook -> pyzmq[version='>=17,<25'] -> zeromq[version='>=4.3.4,<4.4.0a0']
# jupyter_server -> pyzmq[version='>=24'] -> zeromq[version='>=4.3.4,<4.4.0a0']
# nbclassic -> pyzmq[version='>=17'] -> zeromq[version='>=4.3.4,<4.4.0a0']
# ipykernel -> pyzmq[version='>=20'] -> zeromq[version='>=4.3.4,<4.4.0a0']
# jupyter_client -> pyzmq[version='>=23.0'] -> zeromq[version='>=4.3.4,<4.4.0a0']
# pyzmq -> zeromq[version='>=4.3.4,<4.4.0a0']
#
# Package kiwisolver conflicts for:
# matplotlib-base -> kiwisolver[version='>=1.0.1']
# squarify -> matplotlib-base -> kiwisolver[version='>=1.0.1']
# matplotlib -> matplotlib-base[version='>=3.7.2,<3.7.3.0a0'] -> kiwisolver[version='>=1.0.1']
#
# Package pkgutil-resolve-name conflicts for:
# nbformat -> jsonschema[version='>=2.6'] -> pkgutil-resolve-name[version='>=1.3.10']
# jupyter_events -> jsonschema[version='>=3.2'] -> pkgutil-resolve-name[version='>=1.3.10']
# jsonschema -> pkgutil-resolve-name[version='>=1.3.10']
#
# Package pickleshare conflicts for:
# ipython -> pickleshare
# ipykernel -> ipython[version='>=7.23.1'] -> pickleshare
# jupyter-dash -> ipython -> pickleshare
#
# Package bleach conflicts for:
# nbconvert -> bleach
# nbclassic -> nbconvert[version='>=5'] -> bleach
# jupyter_server -> nbconvert[version='>=6.4.4'] -> bleach
# notebook -> nbconvert[version='>=5'] -> bleach
#
# Package python-fastjsonschema conflicts for:
# nbclassic -> nbformat -> python-fastjsonschema
# plotly -> nbformat[version='>=4.2'] -> python-fastjsonschema
# nbformat -> python-fastjsonschema
# jupyter_server -> nbformat[version='>=5.3.0'] -> python-fastjsonschema
# notebook -> nbformat -> python-fastjsonschema
# nbclient -> nbformat[version='>=5.0'] -> python-fastjsonschema
# nbconvert -> nbformat[version='>=5.1'] -> python-fastjsonschema
#
# Package defusedxml conflicts for:
# jupyter_server -> nbconvert[version='>=6.4.4'] -> defusedxml
# nbclassic -> nbconvert[version='>=5'] -> defusedxml
# notebook -> nbconvert[version='>=5'] -> defusedxml
# nbconvert -> defusedxml
#
# Package terminado conflicts for:
# jupyter_server -> terminado[version='>=0.8.3']
# jupyter_server_terminals -> terminado[version='>=0.8.3']
# nbclassic -> terminado[version='>=0.8.3']
# notebook -> terminado[version='>=0.8.3']
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> terminado[version='>=0.8.3']
#
# Package nbclient conflicts for:
# nbconvert -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# notebook -> nbconvert[version='>=5'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# nbclassic -> nbconvert[version='>=5'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# jupyter_server -> nbconvert[version='>=6.4.4'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
#
# Package pexpect conflicts for:
# ipykernel -> ipython[version='>=7.23.1'] -> pexpect[version='>4.3']
# jupyter-dash -> ipython -> pexpect[version='>4.3']
# ipython -> pexpect[version='>4.3']
#
# Package contourpy conflicts for:
# squarify -> matplotlib-base -> contourpy[version='>=1.0.1']
# matplotlib -> matplotlib-base[version='>=3.7.2,<3.7.3.0a0'] -> contourpy[version='>=1.0.1']
# matplotlib-base -> contourpy[version='>=1.0.1']
#
# Package backcall conflicts for:
# ipython -> backcall
# jupyter-dash -> ipython -> backcall
# ipykernel -> ipython[version='>=7.23.1'] -> backcall
#
# Package lz4-c conflicts for:
# libtiff -> zstd[version='>=1.5.2,<1.6.0a0'] -> lz4-c[version='>=1.9.3,<1.10.0a0|>=1.9.4,<1.10.0a0']
# zstd -> lz4-c[version='>=1.9.3,<1.10.0a0|>=1.9.4,<1.10.0a0']
#
# Package libbrotlicommon conflicts for:
# brotli-bin -> libbrotlidec==1.0.9=h1a28f6b_7 -> libbrotlicommon==1.0.9=h1a28f6b_7
# brotli -> libbrotlidec==1.0.9=h1a28f6b_7 -> libbrotlicommon==1.0.9=h1a28f6b_7
# libbrotlidec -> libbrotlicommon==1.0.9=h1a28f6b_7
# libbrotlienc -> libbrotlicommon==1.0.9=h1a28f6b_7
#
# Package chardet conflicts for:
# pooch -> requests[version='>=2.19.0'] -> chardet[version='>=3.0.2,<4|>=3.0.2,<5']
# folium -> requests -> chardet[version='>=3.0.2,<4|>=3.0.2,<5']
# plotly -> requests -> chardet[version='>=3.0.2,<4|>=3.0.2,<5']
# requests -> chardet[version='>=3.0.2,<4|>=3.0.2,<5']
# jupyter-dash -> requests -> chardet[version='>=3.0.2,<4|>=3.0.2,<5']
#
# Package python-json-logger conflicts for:
# jupyter_server -> jupyter_events[version='>=0.4.0'] -> python-json-logger[version='>=2.0.4']
# jupyter_events -> python-json-logger[version='>=2.0.4']
#
# Package pyopenssl conflicts for:
# requests -> urllib3[version='>=1.21.1,<2'] -> pyopenssl[version='>=0.14']
# urllib3 -> pyopenssl[version='>=0.14']
# conda[version='>=23.7.4'] -> pyopenssl[version='>=16.2.0']
#
# Package click conflicts for:
# dash -> flask[version='>=1.0.4'] -> click[version='>=5.1|>=5.1,<8.0|>=7.1.2|>=8.0']
# flask-compress -> flask -> click[version='>=5.1|>=5.1,<8.0|>=7.1.2|>=8.0']
# flask -> click[version='>=5.1|>=5.1,<8.0|>=7.1.2|>=8.0']
# jupyter-dash -> flask -> click[version='>=5.1|>=5.1,<8.0|>=7.1.2|>=8.0']
#
# Package tinycss2 conflicts for:
# nbclassic -> nbconvert[version='>=5'] -> tinycss2
# notebook -> nbconvert[version='>=5'] -> tinycss2
# jupyter_server -> nbconvert[version='>=6.4.4'] -> tinycss2
# nbconvert -> tinycss2
#
# Package cycler conflicts for:
# matplotlib-base -> cycler[version='>=0.10']
# matplotlib -> matplotlib-base[version='>=3.7.2,<3.7.3.0a0'] -> cycler[version='>=0.10']
# squarify -> matplotlib-base -> cycler[version='>=0.10']
#
# Package libxslt conflicts for:
# nbconvert -> lxml -> libxslt[version='>=1.1.28|>=1.1.28,<2.0.0a0|>=1.1.37,<2.0a0|>=1.1.35,<2.0a0|>=1.1.34,<2.0a0']
# lxml -> libxslt[version='>=1.1.28|>=1.1.28,<2.0.0a0|>=1.1.37,<2.0a0|>=1.1.35,<2.0a0|>=1.1.34,<2.0a0']
#
# Package pure_eval conflicts for:
# ipython -> stack_data -> pure_eval
# stack_data -> pure_eval
#
# Package jaraco.itertools conflicts for:
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# zipp -> jaraco.itertools
#
# Package urllib3 conflicts for:
# jupyter-dash -> requests -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27|>=1.21.1,<2']
# requests -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27|>=1.21.1,<2']
# folium -> requests -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27|>=1.21.1,<2']
# conda[version='>=23.7.4'] -> requests[version='>=2.27.0,<3'] -> urllib3[version='>=1.21.1,<1.27|>=1.21.1,<2']
# pooch -> requests[version='>=2.19.0'] -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27|>=1.21.1,<2']
# plotly -> requests -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27|>=1.21.1,<2']
#
# Package jedi conflicts for:
# jupyter-dash -> ipython -> jedi[version='>=0.10,<0.18|>=0.10|>=0.16|>=0.16,<1.0']
# ipython -> jedi[version='>=0.10,<0.18|>=0.10|>=0.16|>=0.16,<1.0']
# ipykernel -> ipython[version='>=7.23.1'] -> jedi[version='>=0.10,<0.18|>=0.10|>=0.16|>=0.16,<1.0']
#
# Package asttokens conflicts for:
# ipython -> stack_data -> asttokens
# stack_data -> asttokens
#
# Package lerc conflicts for:
# libwebp -> libtiff[version='>=4.2.0,<5.0a0'] -> lerc[version='>=3.0,<4.0a0']
# libtiff -> lerc[version='>=3.0,<4.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> lerc[version='>=3.0,<4.0a0']
# pillow -> libtiff[version='>=4.2.0,<5.0a0'] -> lerc[version='>=3.0,<4.0a0']
#
# Package soupsieve conflicts for:
# beautifulsoup4 -> soupsieve[version='>1.2|>=1.2']
# nbconvert -> beautifulsoup4 -> soupsieve[version='>1.2|>=1.2']
#
# Package argon2-cffi conflicts for:
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> argon2-cffi
# jupyter_server -> argon2-cffi
# nbclassic -> argon2-cffi
# notebook -> argon2-cffi
#
# Package exceptiongroup conflicts for:
# ipython -> exceptiongroup
# ipykernel -> ipython[version='>=7.23.1'] -> exceptiongroup
# jupyter-dash -> ipython -> exceptiongroup
#
# Package munkres conflicts for:
# matplotlib-base -> fonttools[version='>=4.22.0'] -> munkres
# fonttools -> munkres
#
# Package rfc3986-validator conflicts for:
# jupyter_server -> jupyter_events[version='>=0.4.0'] -> rfc3986-validator[version='>=0.1.1']
# jupyter_events -> rfc3986-validator[version='>=0.1.1']
#
# Package parso conflicts for:
# ipython -> jedi[version='>=0.16'] -> parso[version='>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
# jedi -> parso[version='>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
#
# Package fonttools conflicts for:
# matplotlib-base -> fonttools[version='>=4.22.0']
# matplotlib -> matplotlib-base[version='>=3.7.2,<3.7.3.0a0'] -> fonttools[version='>=4.22.0']
# squarify -> matplotlib-base -> fonttools[version='>=4.22.0']
#
# Package unicodedata2 conflicts for:
# fonttools -> unicodedata2[version='>=13.0.0']
# matplotlib-base -> fonttools[version='>=4.22.0'] -> unicodedata2[version='>=13.0.0']
#
# Package matplotlib-base conflicts for:
# matplotlib -> matplotlib-base[version='>=3.4.2,<3.4.3.0a0|>=3.5.0,<3.5.1.0a0|>=3.5.1,<3.5.2.0a0|>=3.5.2,<3.5.3.0a0|>=3.5.3,<3.5.4.0a0|>=3.6.2,<3.6.3.0a0|>=3.7.0,<3.7.1.0a0|>=3.7.1,<3.7.2.0a0|>=3.7.2,<3.7.3.0a0']
# squarify -> matplotlib-base
#
# Package retrying conflicts for:
# dash -> plotly -> retrying[version='>=1.3.3']
# plotly -> retrying[version='>=1.3.3']
# jupyter-dash -> retrying
#
# Package pandocfilters conflicts for:
# nbclassic -> nbconvert[version='>=5'] -> pandocfilters[version='>=1.4.1']
# notebook -> nbconvert[version='>=5'] -> pandocfilters[version='>=1.4.1']
# jupyter_server -> nbconvert[version='>=6.4.4'] -> pandocfilters[version='>=1.4.1']
# nbconvert -> pandocfilters[version='>=1.4.1']
#
# Package libdeflate conflicts for:
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> libdeflate[version='>=1.17,<1.18.0a0|>=1.8,<1.9.0a0']
# libwebp -> libtiff[version='>=4.2.0,<5.0a0'] -> libdeflate[version='>=1.17,<1.18.0a0|>=1.8,<1.9.0a0']
# libtiff -> libdeflate[version='>=1.17,<1.18.0a0|>=1.8,<1.9.0a0']
# pillow -> libtiff[version='>=4.2.0,<5.0a0'] -> libdeflate[version='>=1.17,<1.18.0a0|>=1.8,<1.9.0a0']
#
# Package pandoc conflicts for:
# jupyter_server -> nbconvert -> pandoc[version='>=1.12.1']
# nbclassic -> nbconvert[version='>=5'] -> pandoc[version='>=1.12.1']
# notebook -> nbconvert[version='>=5'] -> pandoc[version='>=1.12.1']
# nbconvert -> pandoc[version='>=1.12.1']
#
# Package giflib conflicts for:
# libwebp -> giflib[version='>=5.2.1,<5.3.0a0']
# pillow -> libwebp[version='>=1.3.2,<2.0a0'] -> giflib[version='>=5.2.1,<5.3.0a0']
#
# Package pyyaml conflicts for:
# dash -> pyyaml[version='>=5.1.1']
# jupyter_server -> jupyter_events[version='>=0.4.0'] -> pyyaml[version='>=5.3']
# jupyter-dash -> dash -> pyyaml[version='>=5.1.1']
# jupyter_events -> pyyaml[version='>=5.3']
#
# Package libwebp-base conflicts for:
# libwebp -> libwebp-base[version='1.2.4.*|1.3.2.*|>=1.3.2,<2.0a0']
# libwebp -> libtiff[version='>=4.2.0,<5.0a0'] -> libwebp-base[version='>=1.2.4,<2.0a0']
# pillow -> libtiff[version='>=4.2.0,<5.0a0'] -> libwebp-base[version='1.2.4.*|1.3.2.*|>=1.2.4,<2.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> libwebp-base[version='>=1.2.0,<1.3.0a0|>=1.3.2,<2.0a0']
# pillow -> libwebp-base[version='>=1.2.0,<1.3.0a0|>=1.3.2,<2.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> libwebp-base[version='>=1.2.4,<2.0a0']
# libtiff -> libwebp-base[version='>=1.2.4,<2.0a0']
#
# Package anyio conflicts for:
# nbclassic -> jupyter_server[version='>=1.8'] -> anyio[version='>=2.0.2|>=3.1.0,<4']
# jupyter_server -> anyio[version='>=2.0.2|>=3.1.0,<4']
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> anyio[version='>=3.1.0,<4']
#
# Package yaml conflicts for:
# dash -> pyyaml[version='>=5.1.1'] -> yaml[version='>=0.2.5,<0.3.0a0']
# pyyaml -> yaml[version='>=0.2.5,<0.3.0a0']
# jupyter_events -> pyyaml[version='>=5.3'] -> yaml[version='>=0.2.5,<0.3.0a0']
#
# Package backports conflicts for:
# backports.functools_lru_cache -> backports
# wcwidth -> backports.functools_lru_cache -> backports
#
# Package dataclasses conflicts for:
# werkzeug -> dataclasses
# flask -> werkzeug[version='>=2.0'] -> dataclasses
#
# Package tqdm conflicts for:
# conda-package-handling -> tqdm
# conda[version='>=23.7.4'] -> tqdm[version='>=4']
# conda[version='>=23.7.4'] -> conda-package-handling[version='>=1.3.0'] -> tqdm
#
# Package werkzeug conflicts for:
# dash -> flask[version='>=1.0.4'] -> werkzeug[version='>=0.14|>=0.15|>=0.15,<2.0|>=2.0|>=2.2.2']
# flask-compress -> flask -> werkzeug[version='>=0.14|>=0.15|>=0.15,<2.0|>=2.0|>=2.2.2']
# flask -> werkzeug[version='>=0.14|>=0.15|>=0.15,<2.0|>=2.0|>=2.2.2']
# jupyter-dash -> flask -> werkzeug[version='>=0.14|>=0.15|>=0.15,<2.0|>=2.0|>=2.2.2']
#
# Package pysocks conflicts for:
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests -> urllib3[version='>=1.21.1,<2'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package libxml2 conflicts for:
# lxml -> libxml2[version='>=2.10.3,<2.11.0a0|>=2.10.4,<2.11.0a0|>=2.9.14,<2.10.0a0|>=2.9.2,!=2.9.11,!=2.9.12|>=2.9.12,<2.10.0a0|>=2.9.10,<2.10.0a0']
# nbconvert -> lxml -> libxml2[version='>=2.10.3,<2.11.0a0|>=2.10.4,<2.11.0a0|>=2.9.14,<2.10.0a0|>=2.9.2,!=2.9.11,!=2.9.12|>=2.9.12,<2.10.0a0|>=2.9.10,<2.10.0a0']
# libxslt -> libxml2[version='>=2.10.3,<2.11.0a0|>=2.10.4,<2.11.0a0|>=2.9.14,<2.10.0a0|>=2.9.10,<2.10.0a0']
#
# Package brotli conflicts for:
# matplotlib-base -> fonttools[version='>=4.22.0'] -> brotli[version='>=1.0.1']
# fonttools -> brotli[version='>=1.0.1']
#
# Package olefile conflicts for:
# pillow -> olefile
# matplotlib-base -> pillow[version='>=6.2.0'] -> olefile
#
# Package async_generator conflicts for:
# nbconvert -> nbclient[version='>=0.5.0'] -> async_generator
# nbclient -> async_generatorThe following specifications were found to be incompatible with your system:
#
#   - feature:/osx-arm64::__osx==14.0=0
#   - feature:|@/osx-arm64::__osx==14.0=0
#   - ipykernel -> __osx
#   - ipython -> __osx
#   - jupyter-dash -> ipykernel -> __osx
#   - nbclassic -> ipykernel -> __osx
#   - notebook -> ipykernel -> __osx
#
# Your installed version is: 14.0
